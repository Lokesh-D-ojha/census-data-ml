# %%
pip install numpy==1.24.4
# Out:
# ...
#      ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#      - -------------------------------------- 0.5/10.9 MB 4.2 MB/s eta 0:00:03
#      ------- -------------------------------- 2.1/10.9 MB 6.5 MB/s eta 0:00:02
#      ------------- -------------------------- 3.7/10.9 MB 7.3 MB/s eta 0:00:01
#      -------------------- ------------------- 5.5/10.9 MB 7.6 MB/s eta 0:00:01
#      -------------------------- ------------- 7.3/10.9 MB 7.8 MB/s eta 0:00:01
#      --------------------------------- ------ 9.2/10.9 MB 7.9 MB/s eta 0:00:01
#      ---------------------------------------  10.7/10.9 MB 8.0 MB/s eta 0:00:01
#      ---------------------------------------- 10.9/10.9 MB 7.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# ...

# %%
pip install ydata‑profiling
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: 'ydata\u2011profiling': Expected end or semicolon (after name and no valid version specifier)
#     ydata\u2011profiling
#          ^
